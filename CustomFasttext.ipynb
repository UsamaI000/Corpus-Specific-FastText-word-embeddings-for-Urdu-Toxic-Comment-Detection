# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path="/content/drive/MyDrive/Roman-Urdu-Toxic-Comments-master/Data/"

# %%
customembeddingfile = '/content/drive/MyDrive/Roman-Urdu-Toxic-Comments-master/emb/embeddings_ft.bin'
# preembeddingfile =
# Out:
# '/content/drive/MyDrive/Roman-Urdu-Toxic-Comments-master/emb/embeddings_ft.bin'

# %%
import pickle

with open('/content/drive/MyDrive/Roman-Urdu-Toxic-Comments-master/emb/custom_tokenizer.pickle', 'rb') as handle:
    tokenizer = pickle.load(handle)

# %%
len(tokenizer.word_docs.values())
# Out:
# 51706

# %%
myvocab = tokenizer.word_docs.keys()
# Out:
# dict_keys(['لل', 'طریقہ', 'ہوا', 'نیا', 'آتا', 'کیا', 'بتاتا', 'مارا', 'ہے', 'جو', 'پر', 'تمنے', 'لعنت', 'لاکھ', 'پورے', 'بہن', 'لوڑی', 'ایک', 'دو', 'تیری', 'کے', 'لئے', 'ہو', 'کی', 'چیز', 'شکل', 'منٹ', 'دکھانے', 'بیوقوف', 'لوگوں', 'بنا', 'بکواس', 'رہے', 'کو', 'دس', 'او', 'بھی', 'دے', 'لعنتی', 'لن', 'کا', 'چاہئے', 'ہونا', 'تھا', 'گولڈ', 'شادی', 'ایسے', 'پہ', 'آجا', 'میرا', 'چوس', 'لوڑا', 'کھا', 'چڑھ', 'بہنچود', 'مادرچود', 'تو', 'نونو', 'چوپ', 'میری', 'چوتڑ', 'نسل', 'بھڑوا', 'چود', 'لوڑے', 'لے', 'گانڈ', 'مار', 'لا', 'چوپا', 'دفع', 'ہوجا', 'گدھا', 'گشتی', 'بچے', 'حرامزادہ', 'حرامزادی', 'کمینہ', 'کمینی', 'پین', 'انگریز', 'پینوچ', 'بڈھے', 'نی', 'نا', 'بچہ', 'دا', 'یون', 'پھدی', 'کپی', 'کوسا', 'ماں', 'یاوا', 'بین', 'یووا', 'کس', 'مادری', 'کتے', 'کتی', 'سور', 'سٹ', 'پنیوی', 'للا', 'یہ', 'بیہنچود', 'ہیں', 'اس', 'میں', 'ڈھوئی', 'ماروں', 'گا', 'مارو', 'کنجر', 'بنڈ', 'والی', 'پریش', 'لنڈ', 'مادر', 'ماںیدا', 'رنڈی', 'تامل', 'ٹٹے', 'چوسو', 'موترے', 'کتا', 'چودیں', 'الو', 'پٹھہ', 'پٹھی', 'بھائی',
# ...

# %%
import gensim

# %%
from gensim.models.wrappers import FastText

model = FastText.load_fasttext_format("/content/drive/MyDrive/Roman-Urdu-Toxic-Comments-master/Data/cc.ur.300.bin")

# %%
model.wv.vocab.keys()

# %%
loaded_model = FastText.load(customembeddingfile)
